# %%
from dipy.io.streamline import load_tck
from dipy.io.streamline import load_trk

from dipy.tracking.streamline import transform_streamlines
import nibabel as nib
import numpy as np
from dipy.viz import actor, window
from dipy.tracking.utils import length
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# In  [17]:
# Line 10:    %matplotlib inline
#
# ValueError: magics not found
# ---------------------------------------------------------------------------

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %%
import dipy as dp
print(dp.__version__)
# Out:
# 1.2.0

# %%
bundle=load_tck("/NAS/dumbo/protocoles/CogPhenoPark/TractSeg_output/420620AC050813/bundles/SLF_III_right_filtered.tck","/NAS/dumbo/protocoles/CogPhenoPark/TractSeg_output/420620AC050813/FA.nii.gz")
FA_img = nib.load("/NAS/dumbo/protocoles/CogPhenoPark/TractSeg_output/420620AC050813/FA.nii.gz")
FA = FA_img.get_fdata()
streamlines = transform_streamlines(bundle.streamlines, np.linalg.inv(FA_img.affine))

# %%
#bundle=load_tck("/NAS/deathrow/protocoles/MEDU_ST_PHI/tracto/PAT00001/ORIG_DTI_MB_2500_600_15_9_3X3/tracks_L5_L_prob_10000_filtered.tck","/NAS/deathrow/protocoles/MEDU_ST_PHI/tracto/PAT00020/ORIG_DTI_MB_2500_600_15_9_3X3/adc_PAT00020_ORIG_DTI_MB_2500_600_15_9_3X3.nii.gz")
bundle=load_tck("/NAS/deathrow/protocoles/MEDU_ST_PHI/tracto/PAT00001/ORIG_DTI_MB_2500_600_15_9_3X3/tracks_L5_R_prob_10000_filtered_ex.tck","/NAS/deathrow/protocoles/MEDU_ST_PHI/tracto/PAT00001/ORIG_DTI_MB_2500_600_15_9_3X3/adc_PAT00001_ORIG_DTI_MB_2500_600_15_9_3X3.nii.gz")

FA_img = nib.load("/NAS/deathrow/protocoles/MEDU_ST_PHI/tracto/PAT00001/ORIG_DTI_MB_2500_600_15_9_3X3/adc_PAT00001_ORIG_DTI_MB_2500_600_15_9_3X3.nii.gz")

FA = FA_img.get_fdata()
streamlines = transform_streamlines(bundle.streamlines, np.linalg.inv(FA_img.affine))

# %%
renderer = window.Scene()
sl_actor = actor.streamtube(streamlines, linewidth=0.1, opacity=0.2)
renderer.add(sl_actor)
window.show(renderer)

# %%
renderer = window.Scene()

streamlines = transform_streamlines(bundle.streamlines, np.linalg.inv(FA_img.affine))
hue = (0.0, 0.0)  # red only
saturation = (0.0, 1.0)  # white to red

lut_cmap = actor.colormap_lookup_table(hue_range=hue,saturation_range=saturation)

#stream_actor3 = actor.line(bundle_native, fa, linewidth=0.1,lookup_colormap=lut_cmap)
bar2 = actor.scalar_bar(lut_cmap)
renderer.add(bar2)

sl_actor = actor.streamtube(streamlines,FA, linewidth=0.1, opacity=0.2,lookup_colormap=lut_cmap)
renderer.add(sl_actor)
window.show(renderer)

# %%
np.nanmin(FA)
# Out:
# -1.1888659717227884e+22

# %%
bundle=load_trk("/NAS/deathrow/mri_data/test_NAILA/Tests_Dti_Multi_Shells/results/8_25_45_MB3/Tracking/8_25_45_MB3__tracking.trk\
","/NAS/deathrow/mri_data/test_NAILA/Tests_Dti_Multi_Shells/results/8_25_45_MB3/Resample_DWI/8_25_45_MB3__dwi_resampled.nii.gz")

# %%
print(len(bundle.streamlines))
val=list(length(bundle.streamlines))
print(np.mean(val),np.std(val))
print(len(val))
# Out:
# 2640064
# 54.545315 27.823849
# 2640064
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# In  [13]:
# Line 5:     plt.hist(val, bins=100, histtype='step')
#
# NameError: name 'plt' is not defined
# ---------------------------------------------------------------------------

# %%
plt.hist(val, bins=100, histtype='step')
plt.show()
# Out:
# /home/global/anaconda37/bin/xpython:2: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
renderer = window.Scene()
sl_actor = actor.streamtube(bundle.streamlines, linewidth=0.1, opacity=0.2)
renderer.add(sl_actor)
window.show(renderer)
