# %%
import os, sys
import pydicom as dcm
import pandas as pd
import matplotlib.pyplot as plt #graphiques
from os import listdir
from os.path import isfile, join
import glob
import dipy as dp
import nibabel as nb
# %matplotlib inline
import numpy as np

# %%
#PATH_DIR = join('/home','RECPAR','VEDE^CATHERINE^^_I_CERE_2022-11-16')
PATH_DIR = join('/NAS','deathrow','protocoles','DTI_FACIAL','VEDE^CATHERINE^^_I_CERE_2022-11-16')

# %%
print(dp.__version__)
# Out:
# 1.5.0

# %%
def display_mri(data, title=None, cmap="gray", vmin=-1, vmax=0.8): 
    vmin=np.min(data)
    vmax=np.max(data)
    fig,axs = plt.subplots(nrows=1, ncols=5, figsize=(20,8))
    for ax in axs:
        ax.set_xticks(())
        ax.set_yticks(())
    if title:
        fig.suptitle(title)
    axs[0].imshow(data[:,:,5], cmap=cmap, vmin=vmin, vmax=vmax)
    axs[1].imshow(data[:,:,9], cmap=cmap, vmin=vmin, vmax=vmax)
    axs[2].imshow(data[:,:,13], cmap=cmap, vmin=vmin, vmax=vmax)
    axs[3].imshow(data[:,:,17], cmap=cmap, vmin=vmin, vmax=vmax)
    axs[4].imshow(data[:,:,21], cmap=cmap, vmin=vmin, vmax=vmax)    
    fig.tight_layout()
    plt.show()
    plt.savefig(join(PATH_DIR,'sliceofColorCodedVect.jpeg'))

# %%
mask = nb.load(join(PATH_DIR,"auto-mask.nii.gz"))

# %% [markdown]
# Pour obtenir des vecteur codé en RGB
# dwi2tensor autodwi_PreProc_Unbias.mif - | tensor2metric - -vec - | mrcalc - -abs colorCodedVec.nii.gz

# %%
data_colorfa = nb.load(join(PATH_DIR,"colorCodedVec.nii.gz"))
data_dti=data_colorfa.get_fdata();
plt.imshow(data_dti[:,:,12])
plt.colorbar()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
display_mri(data_dti)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for cpt in [17,18,19,20]:
    plt.imshow(data_dti[:,:,cpt])
    plt.savefig(join(PATH_DIR,'sliceofColorCodedVect_'+str(cpt)+'.jpeg'))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
bundle = nib.streamlines.load(join(PATH_DIR,'Tracto_testRV_corr.tck')
