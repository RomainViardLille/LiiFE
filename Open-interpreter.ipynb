# %%
pip install open-interpreter
# Out:
# ...
#   Obtaining dependency information for open-interpreter from https://files.pythonhosted.org/packages/d1/73/c8c4d327e2d7e60e37bc11f205bca09e3f3ac2cce87d1bd61f8e01184ee0/open_interpreter-0.2.4-py3-none-any.whl.metadata
#   Using cached open_interpreter-0.2.4-py3-none-any.whl.metadata (15 kB)
# ...
#   Obtaining dependency information for aifs<0.0.10,>=0.0.9 from https://files.pythonhosted.org/packages/60/0f/1ebc6fe2d261f398a503dcbf3ba0cfcbc920fa1ed3506fdb81854021d3b0/aifs-0.0.9-py3-none-any.whl.metadata
#   Using cached aifs-0.0.9-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Obtaining dependency information for fastapi<0.111.0,>=0.110.0 from https://files.pythonhosted.org/packages/f0/f7/ea860cb8aa18e326f411e32ab537424690a53db20de6bad73d70da611fae/fastapi-0.110.0-py3-none-any.whl.metadata
#   Using cached fastapi-0.110.0-py3-none-any.whl.metadata (25 kB)
# ...

# %%
# !interpreter
# Out:
# Traceback (most recent call last):
#   File "/home/global/Anaconda3-2023.09/bin/interpreter", line 5, in <module>
#     from interpreter.terminal_interface.start_terminal_interface import main
#   File "/home/global/Anaconda3-2023.09/lib/python3.11/site-packages/interpreter/__init__.py", line 2, in <module>
#     from .core.core import OpenInterpreter
#   File "/home/global/Anaconda3-2023.09/lib/python3.11/site-packages/interpreter/core/core.py", line 17, in <module>
#     from .llm.llm import Llm
#   File "/home/global/Anaconda3-2023.09/lib/python3.11/site-packages/interpreter/core/llm/llm.py", line 1, in <module>
#     import litellm
#   File "/home/global/Anaconda3-2023.09/lib/python3.11/site-packages/litellm/__init__.py", line 618, in <module>
#     from .main import *  # type: ignore
#     ^^^^^^^^^^^^^^^^^^^
#   File "/home/global/Anaconda3-2023.09/lib/python3.11/site-packages/litellm/main.py", line 68, in <module>
#     from .llms.azure_text import AzureTextCompletion
# ...

# %%
pip install socksio
# Out:
# ...
#   Obtaining dependency information for socksio from https://files.pythonhosted.org/packages/37/c3/6eeb6034408dac0fa653d126c9204ade96b819c936e136c5e8a6897eee9c/socksio-1.0.0-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip
