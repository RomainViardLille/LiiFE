# %%
pip install dcm2niix
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.4/451.4 kB 2.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for dcm2niix: filename=dcm2niix-1.0.20220715-cp38-cp38-linux_x86_64.whl size=576082 sha256=f47a3b7c865a10d5ddf2deeb224e606f6aa44a2044c126fbbb018809c26af4f2
#   Stored in directory: /home/youssef/.cache/pip/wheels/6e/ad/be/de4334a6bec64465e158e35614ccbff0fbd9080f684c1daace
# Successfully built dcm2niix
# ...
#
# [notice] A new release of pip is available: 23.1.1 -> 23.2.1
# [notice] To update, run: /NAS/deathrow/vincent/anaconda3/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nipype
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.1 -> 23.2.1
# [notice] To update, run: /NAS/deathrow/vincent/anaconda3/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.1
#     Uninstalling pip-23.1.1:
#       Successfully uninstalled pip-23.1.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, sys
import pydicom as dcm
import pandas as pd
import matplotlib.pyplot as plt #graphiques
from os import listdir
from os.path import isfile, join
#onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
import glob
import dcm2niix as dc
#len(glob.glob(join(mypath,"*","*","MR*"),recursive=True))
from nipype.interfaces.dcm2nii import Dcm2niix

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
test_load = nib.load("/NAS/dumbo/protocoles/HAMSI/nifti_CHU/1.3.51.0.1.1.10.49.10.222.5943231.5943554/T1.nii.gz").get_fdata()
test_load.shape
# Out:
# (272, 512, 512)

# %%
test = test_load[:,:,59]
plt.imshow(test)
plt.show()

# %%
test2_load = nib.load("/NAS/dumbo/protocoles/HAMSI/nifti_CHU/1.3.51.0.1.1.10.49.10.222.7524515.7525759/T1.nii.gz").get_fdata()
test2_load.shape
# Out:
# (272, 512, 512)

# %%
test2 = test2_load[:,:,59]
plt.imshow(test2)
plt.show()

# %%
for i in range(5):
    plt.subplot(5, 5,i + 1)
    plt.imshow(test2[:,:,59 + i])
    plt.gcf().set_size_inches(10, 10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 for i in range(5):
#       2     plt.subplot(5, 5,i + 1)
# ----> 3     plt.imshow(test2[:,:,59 + i])
#       4     plt.gcf().set_size_inches(10, 10)
#       5 plt.show()
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
test_load = nib.load("/NAS/dumbo/protocoles/HAMSI/nifti_CHU/1.3.51.0.1.1.10.49.10.222.5943231.5943554/FLAIR.nii.gz").get_fdata()
test_load.shape
# Out:
# (208, 512, 512)

# %%
test = test_load[:,:,59]
plt.imshow(test)
plt.show()
