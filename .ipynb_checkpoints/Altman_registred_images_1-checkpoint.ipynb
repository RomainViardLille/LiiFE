# %%
conda update nibabel
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /home/global/anaconda37
#   package name: nibabel
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update numpy
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/global/anaconda37
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1v-h7f8727e_0 --> 1.1.1w-h7f8727e_0
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /home/global/anaconda37
#   uid: 2054
#   gid: 500
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/global/anaconda37
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1v-h7f8727e_0 --> 1.1.1w-h7f8727e_0
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /home/global/anaconda37
#   uid: 2054
#   gid: 500
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update matplotlib
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/global/anaconda37
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1v-h7f8727e_0 --> 1.1.1w-h7f8727e_0
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /home/global/anaconda37
#   uid: 2054
#   gid: 500
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import nibabel as nib
import numpy as np
from scipy.ndimage import zoom
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def bland_altman_plot(image1, image2):
    # Get image data as numpy arrays
    data1 = image1.get_fdata()
    data2 = image2.get_fdata()

    # Calculate the mean and the difference between the two images
    mean = (data1 + data2) / 2
    diff = data1 - data2

    # Create the Bland-Altman plot
    plt.figure(figsize=(8, 6))
    plt.scatter(mean, diff, alpha=0.5)
    plt.axhline(np.mean(diff), color='red', linestyle='--', label='Mean Difference')
    plt.axhline(1.96 * np.std(diff), color='gray', linestyle='--', label='Upper Limit of Agreement')
    plt.axhline(-1.96 * np.std(diff), color='gray', linestyle='--', label='Lower Limit of Agreement')

    # Customize the plot
    plt.xlabel('Mean of Measurements')
    plt.ylabel('Difference between Measurements')
    plt.title('Bland-Altman Plot')
    plt.legend()

    # Show the plot
    plt.grid(True)
    plt.show()

# %%
def bland_altman_plot2(image1, image2):
    # Calculate the mean and the difference between the two images
    mean = (image1.get_fdata() + image2.get_fdata()) / 2
    diff = image1.get_fdata() - image2.get_fdata()

    # Create the Bland-Altman plot
    plt.figure(figsize=(8, 6))
    #plt.scatter(mean, diff, s=20, c='blue', alpha=0.5)
    #plt.axhline(y=np.mean(diff), color='red', linestyle='--')
    plt.scatter(mean, diff, alpha=0.5)
    plt.axhline(np.mean(diff), color='red', linestyle='--', label='Mean Difference')
    plt.axhline(1.96 * np.std(diff), color='gray', linestyle='--', label='Upper Limit of Agreement')
    plt.axhline(-1.96 * np.std(diff), color='gray', linestyle='--', label='Lower Limit of Agreement')
    plt.xlabel('Mean of Images 1 and 2')
    plt.ylabel('Difference (Image 1 - Image 2)')
    plt.title('Bland-Altman Plot')
    plt.grid(True)

    # Show the plot
    plt.show()

# %%
def bland_altman_plot3(image_path1, image_path2):
 
    # Load the NIfTI images
    #image1 = nib.load(image_path1)
    #image2 = nib.load(image_path2)
    ''''
    # Extract the voxel values as numpy arrays
    data1 = image1.get_fdata()
    data2 = image2.get_fdata()
    
    # Flatten the 3D or 4D data arrays into 1D arrays
    data1_flat = data1.flatten()
    data2_flat = data2.flatten()
    
    # Calculate the differences and averages between the two sets of measurements
    diff = data1_flat - data2_flat
    mean = (data1_flat + data2_flat) / 2
    
    # Calculate the mean difference
    mean_diff = np.mean(diff)
    ''''
    data1 = image1.get_fdata()
    data2 = image2.get_fdata()

    # Calculate the mean and the difference between the two images
    mean = (data1 + data2) / 2
    diff = data1 - data2

    
    # Calculate the limits of agreement (±1.96 standard deviations)
    sd_diff = np.std(diff, ddof=1)
    limit_of_agreement_upper = mean_diff + 1.96 * sd_diff
    limit_of_agreement_lower = mean_diff - 1.96 * sd_diff
    
    # Create the Bland-Altman plot
    plt.figure(figsize=(8, 6))
    plt.scatter(mean, diff, s=30, c='b', marker='o', alpha=0.7)
    plt.axhline(y=mean_diff, color='r', linestyle='--', label=f'Mean Difference = {mean_diff:.2f}')
    plt.axhline(y=limit_of_agreement_upper, color='g', linestyle='--', label='+1.96 SD')
    plt.axhline(y=limit_of_agreement_lower, color='g', linestyle='--', label='-1.96 SD')
    plt.title('Bland-Altman Plot')
    plt.xlabel('Average')
    plt.ylabel('Difference')
    plt.legend()
    #plt.grid(True)
    
    # Show the plot
    plt.show()
# Out:
#   File "/tmp/ipykernel_3515673/2551959068.py", line 21
#     ''''
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
image_file1 = "/NAS/dumbo/protocoles/HAMSI/OurData4Mispel_T1Gado/Brains/CHU/Pat8_T1Gado_CHU_brain.nii.gz"
image_file2 = "/NAS/dumbo/protocoles/HAMSI/OurData4Mispel_T1Gado/Brains_Registered/COL_registred_on_CHU/Pat8_COL_registered.nii.gz"

# Load NIfTI images
image1 = nib.load(image_file1)
image2 = nib.load(image_file2)

bland_altman_plot2(image1 , image2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3515673/3242554028.py in <module>
#       6 image2 = nib.load(image_file2)
#       7
# ----> 8 bland_altman_plot2(image1 , image2)
#
# /tmp/ipykernel_3515673/571713763.py in bland_altman_plot2(image1, image2)
#      18
#      19     # Show the plot
# ---> 20     plt.show()
#
# ~/.local/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# /home/global/anaconda37/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      90             display(
#      91                 figure_manager.canvas.figure,
# ---> 92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93             )
# ...

# %%
image_file1 = "/NAS/dumbo/protocoles/HAMSI/OurData4Mispel_T1Gado/Brains/CHU/Pat8_T1Gado_CHU_brain.nii.gz"
image_file2 = "/NAS/dumbo/protocoles/HAMSI/OurData4Mispel_T1Gado/Brains_Registered/COL_registred_on_CHU/Pat8_COL_registered.nii.gz"
plt.hist(image1.get_fdata().ravel(),50,range=(10,500))
plt.hist(image2.get_fdata().ravel(),50,range=(10,500))
# Out:
# (array([1.074071e+06, 1.331151e+06, 3.696312e+06, 3.920703e+06,
#         2.049740e+05, 2.206700e+04, 7.896000e+03, 2.782000e+03,
#         9.180000e+02, 1.680000e+02, 1.000000e+01, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00]),
#  array([ 10. ,  19.8,  29.6,  39.4,  49.2,  59. ,  68.8,  78.6,  88.4,
#          98.2, 108. , 117.8, 127.6, 137.4, 147.2, 157. , 166.8, 176.6,
# ...

# %%
def display_mri(data,slice=None,save=None,title=None,cmap="gray",vmin=-1,vmax=0.8):
    if save==None :
        slice=[int(1*data.shape[2]/6),int(2*data.shape[2]/6),int(3*data.shape[2]/6),int(4*data.shape[2]/6),int(5*data.shape[2]/6)]   
    vmin=np.min(data)
    vmax=np.max(data)
    fig,axs=plt.subplots(nrows=1,ncols=5,figsize=(20,8))
    for ax in axs:
        ax.set_xticks(())
        ax.set_yticks(())
    if title:
        fig.suptitle(title)
    axs[0].imshow(data[:,:,slice[0]],cmap=cmap,vmin=vmin,vmax=vmax)
    axs[1].imshow(data[:,:,slice[1]],cmap=cmap,vmin=vmin,vmax=vmax)
    axs[2].imshow(data[:,:,slice[2]],cmap=cmap,vmin=vmin,vmax=vmax)
    axs[3].imshow(data[:,:,slice[3]],cmap=cmap,vmin=vmin,vmax=vmax)
    axs[4].imshow(data[:,:,slice[4]],cmap=cmap,vmin=vmin,vmax=vmax)
    fig.tight_layout()
    if save:
        plt.savefig(save,transparent=False)
    plt.show()

# %%
plt.hist(image1.get_fdata().ravel(,50,range=(10,)500))

# %%
#slice=[60,70,75,80,100]
vox=image1.get_fdata()
print(vox.shape)
display_mri(vox)
# Out:
# (272, 512, 512)

# %%
display_mri(image1.get_fdata())

# %%
display_mri(image2.get_fdata())

# %%
display_mri(image1.get_fdata()-image2.get_fdata())
