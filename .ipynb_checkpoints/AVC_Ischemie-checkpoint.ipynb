# %%
import os
import glob
import pandas as pd 
import numpy as np
import plotnine as p9
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
CQ_FILE=os.path.join("/NAS","dumbo","protocoles","AVC_ISCHEMIE","data_cog_EtudeCorrVol.xlsx")
CQData = pd.read_excel(CQ_FILE,index_col=0,engine='openpyxl')

# %%
CQData.corr()
# Out:
#                                   ALERTE_PHAS_SANS_AVERTISSEUR  \
# ALERTE_PHAS_SANS_AVERTISSEUR                          1.000000
# ALERTE_PHAS_AVEC_AVERTISSEUR                          0.847588
# ADS_VISUEL_I_TEMPS                                   -0.017288
# ADS_AUDITIF_ET_VISUEL_I_OMISSION                      0.273569
# ADS_AUDITIFVISUEL_1_ERREUR                            0.095172
# VIGILANCE_TEMPS                                       0.094713
# VIGILANCE_OMISSIONS                                   0.363547
# VIGILANCE_ERREUR                                      0.039206
# D2_GZ_F                                              -0.279793
# Volume                                                0.176300
#
#                                   ALERTE_PHAS_AVEC_AVERTISSEUR  \
# ALERTE_PHAS_SANS_AVERTISSEUR                          0.847588
# ALERTE_PHAS_AVEC_AVERTISSEUR                          1.000000
# ADS_VISUEL_I_TEMPS                                   -0.105160
# ...

# %%
np.mean(CQData.corr())
# Out:
# ALERTE_PHAS_SANS_AVERTISSEUR        0.259301
# ALERTE_PHAS_AVEC_AVERTISSEUR        0.270712
# ADS_VISUEL_I_TEMPS                  0.057140
# ADS_AUDITIF_ET_VISUEL_I_OMISSION    0.224762
# ADS_AUDITIFVISUEL_1_ERREUR          0.166657
# VIGILANCE_TEMPS                     0.206644
# VIGILANCE_OMISSIONS                 0.310515
# VIGILANCE_ERREUR                    0.068428
# D2_GZ_F                            -0.056898
# Volume                              0.265048
# dtype: float64

# %%
CQ_FILE=os.path.join("/NAS","dumbo","protocoles","FAIRPARKII","resT2Struct.csv")
val = pd.read_csv(CQ_FILE,index_col=0)

# %%
val.describe()
# Out:
#             GPe_L       GPe_R       GPi_L       GPi_R        RN_L        RN_R  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean    28.458850   28.220359   31.459621   30.726875   32.114673   31.533394
# std      6.739122    6.310018    7.204419    7.303798    4.831026    5.450551
# min     14.162648   15.066350   18.377015   19.249264   20.964401   22.648942
# 25%     25.544570   25.094008   28.878201   27.781331   29.565729   29.137398
# 50%     28.044109   27.656521   30.983878   30.072668   31.659884   30.884374
# 75%     30.234139   30.036058   33.608124   32.726561   34.102292   33.268508
# max    115.333570  100.062767  128.174183  127.260114   76.970075   97.816854
#
#              SN_L        SN_R       STh_L       STh_R  ...  Left_thalamus  \
# count  300.000000  300.000000  298.000000  299.000000  ...     300.000000
# mean    28.595190   29.229299   32.499948   30.812974  ...      38.535259
# ...

# %%
val.mean()+(2*val.std())
# Out:
# GPe_L                    41.937093
# GPe_R                    40.840395
# GPi_L                    45.868458
# GPi_R                    45.334470
# RN_L                     41.776724
# RN_R                     42.434497
# SN_L                     41.667678
# SN_R                     43.201293
# STh_L                    46.564248
# STh_R                    46.110546
# STR_L                    44.583166
# STR_R                    44.516946
# Left_ventricle           58.854511
# Right_ventricle          59.186933
# Left_caudate             44.893022
# Right_caudate            43.543492
# Left_putamen             42.426169
# Right_putamen            42.054852
# Left_thalamus            44.597724
# Right_thalamus           44.696760
# Left_globus_pallidus     40.346422
# Right_globus_pallidus    38.650786
# Left_hipocampus          46.535026
# Right_hipocampus         50.695130
# Left_amigdala            47.787459
# Right_amigdala           51.881474
# Left_accumbens           47.799360
# ...

# %%
val.boxplot()
# Out:
# <AxesSubplot:>

# %%
for col in val.columns:
    q_low = val["GPe_L"].mean()-2*(val["GPe_L"].std()) #val["GPe_L"].quantile(0.01)
    q_hi  = val["GPe_L"].mean()+2*(val["GPe_L"].std()) #val["GPe_L"].quantile(0.99)
    val_exclu = val[(val["GPe_L"] > q_hi) & (val["GPe_L"] < q_low)]
    val = val[(val["GPe_L"] < q_hi) & (val["GPe_L"] > q_low)]
    
    print("col : ",col,val.shape[0])
# Out:
# col :  GPe_L 293
# col :  GPe_R 279
# col :  GPi_L 266
# col :  GPi_R 254
# col :  RN_L 248
# col :  RN_R 243
# col :  SN_L 241
# col :  SN_R 239
# col :  STh_L 239
# col :  STh_R 239
# col :  STR_L 239
# col :  STR_R 239
# col :  Left_ventricle 239
# col :  Right_ventricle 239
# col :  Left_caudate 239
# col :  Right_caudate 239
# col :  Left_putamen 239
# col :  Right_putamen 239
# col :  Left_thalamus 239
# col :  Right_thalamus 239
# col :  Left_globus_pallidus 239
# col :  Right_globus_pallidus 239
# col :  Left_hipocampus 239
# col :  Right_hipocampus 239
# col :  Left_amigdala 239
# col :  Right_amigdala 239
# col :  Left_accumbens 239
# col :  Right_accumbens 239

# %%
val.keys()
# Out:
# Index(['GPe_L', 'GPe_R', 'GPi_L', 'GPi_R', 'RN_L', 'RN_R', 'SN_L', 'SN_R',
#        'STh_L', 'STh_R', 'STR_L', 'STR_R', 'Left_ventricle', 'Right_ventricle',
#        'Left_caudate', 'Right_caudate', 'Left_putamen', 'Right_putamen',
#        'Left_thalamus', 'Right_thalamus', 'Left_globus_pallidus',
#        'Right_globus_pallidus', 'Left_hipocampus', 'Right_hipocampus',
#        'Left_amigdala', 'Right_amigdala', 'Left_accumbens', 'Right_accumbens'],
#       dtype='object')

# %%
val.boxplot()
# Out:
# <AxesSubplot:>

# %%
CQ_FILE=os.path.join("/NAS","dumbo","protocoles","FAIRPARKII","resT2Struct_W00.csv")
val_W00 = pd.read_csv(CQ_FILE,index_col=0)

# %%
CQ_FILE=os.path.join("/NAS","dumbo","protocoles","FAIRPARKII","resT2Struct_W36.csv")
val_W36 = pd.read_csv(CQ_FILE,index_col=0)

# %%
for col in "SN_L":#val.columns:
    q_low = val["GPe_L"].mean()-2*(val["GPe_L"].std()) #val["GPe_L"].quantile(0.01)
    q_hi  = val["GPe_L"].mean()+2*(val["GPe_L"].std()) #val["GPe_L"].quantile(0.99)
    val_exclu = val[(val["GPe_L"] > q_hi) & (val["GPe_L"] < q_low)]
    val = val[(val["GPe_L"] < q_hi) & (val["GPe_L"] > q_low)]
    
    print("col : ",col,val.shape[0])

# %%
val_diff=val_W00-val_W36

# %%
"SN_L","SN_R","left_putamen","Right_putamen","Left_caudate","Right_caudate","Left_globus_pallidus","Right_globus_pallidus","Left_thalamus","Right_thalamus","STN_L","STN_R"
sns.violinplot(data=val_diff["SN_L"])
# Out:
# <AxesSubplot:>
