# %%
import os, sys, glob
import pydicom as dcm
import pandas as pd
import matplotlib.pyplot as plt #graphiques
from nipype.interfaces.dcm2nii import Dcm2niix
import numpy as np
import matplotlib as plt
import nibabel as nb
from nibabel.freesurfer.mghformat import load
from brainspace.plotting import plot_hemispheres
from brainspace.mesh.mesh_io import read_surface
from brainspace.datasets import load_conte69
import nibabel.freesurfer as nifs
import seaborn as sns
from scipy.stats import linregress
# %matplotlib inline
import scipy.stats as stats
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f84fb953-ee46-4a52-a78e-d26ea5d1b7c0'>
#   <div id="d1b2e6a0-7417-4113-bccb-03239bb63900" data-root-id="f84fb953-ee46-4a52-a78e-d26ea5d1b7c0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"bc9adc8e-9a9c-4d53-8cbc-218796c62a8d":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f84fb953-ee46-4a52-a78e-d26ea5d1b7c0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"dc00cf43-ee7b-4437-ad7b-4dc6f376883b","attributes":{"plot_id":"f84fb953-ee46-4a52-a78e-d26ea5d1b7c0","comm_id":"c80d716a0b864b0db695b2b3e2cb081a","client_comm_id":"0a2288f0fb1b44978965c4ba1e2dddeb"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"bc9adc8e-9a9c-4d53-8cbc-218796c62a8d","roots":{"f84fb953-ee46-4a52-a78e-d26ea5d1b7c0":"d1b2e6a0-7417-4113-bccb-03239bb63900"},"root_ids":["f84fb953-ee46-4a52-a78e-d26ea5d1b7c0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
STUDY_PATH="/NAS/tupac/protocoles/Strokdem/"
TS_PATH=os.path.join(STUDY_PATH,"TractSeg")
OUT_PATH=os.path.join(TS_PATH,"data","disconn")
CODE_DIR=os.path.join(TS_PATH,"code")
LOG_DIR=os.path.join(CODE_DIR,"log")
BIDS_DIR=os.path.join("/NAS","deathrow","renaud","dti_disconnection","bids_db")
BIDS_OUT_DIR=os.path.join("/NAS","deathrow","renaud","dti_disconnection","bids_db","derivatives2")
LD_DIR=os.path.join(STUDY_PATH,"Radiomique_SB_LoicDuron_2021","FreeSurfer_Output")
RL_DIR=os.path.join("/NAS","deathrow","renaud","dti_disconnection","bids_proc","freesurfer")
CB_DIR=os.path.join(STUDY_PATH,"FS5.1_T2mask")

# %%
df_air_M6 = pd.read_excel(os.path.join(STUDY_PATH,"ListePtsAIRSTroke_M6.xlsx"),index_col=0,engine='openpyxl')
print(len(list(df_air_M6.index.dropna())))
df_air_M36 = pd.read_excel(os.path.join(STUDY_PATH,"ListePtsAIRSTroke_M36.xlsx"),index_col=0,engine='openpyxl')
print(len(list(df_air_M36.index.dropna())))
# Out:
# 163
# 127

# %%
df_corr= pd.read_excel(os.path.join(STUDY_PATH,"Corresp_ID.xls"),index_col=0,engine='xlrd')

# %% [markdown]
# Remarque(s)
# les freesurfers sont dispatchés dans 3 repertoires :
#
#     FS51_DIR="/NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/"
#     LD_DIR="/NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/"
#     RL_DIR="/NAS/deathrow/renaud/dti_disconnection/bids_proc/freesurfer/"

# %%
TIME="M6"
TYPE="thickness"
SMT="5"
print("******************\nM6\n******************")
for SUBJ in df_corr.loc[list(df_air_M6.index.dropna())]['ID_IRM'].dropna() :
    TMP_F=os.path.join(TS_PATH,'CTsmoothed',SUBJ+'_'+TIME+"_rh."+TYPE+"."+SMT+".mgh")
    TMP_F_LD=os.path.join(LD_DIR,SUBJ)
    TMP_F_RL=os.path.join(RL_DIR,f"{SUBJ}_{TIME}")
    TMP_F_CB=os.path.join(CB_DIR,f"{SUBJ}_{TIME}")
    if not (os.path.exists(TMP_F) or os.path.exists(TMP_F_LD) or os.path.exists(TMP_F_RL) or os.path.exists(TMP_F_CB)) :
        print(f"NOK pour {SUBJ} : {TMP_F_LD}")

print("******************\nM36\n******************")
TIME="M36"
for SUBJ in df_corr.loc[list(df_air_M36.index.dropna())]['ID_IRM'].dropna() :
    TMP_F=os.path.join(TS_PATH,'CTsmoothed',SUBJ+'_'+TIME+"_rh."+TYPE+"."+SMT+".mgh")
    TMP_F_LD=os.path.join(LD_DIR,SUBJ)
    TMP_F_RL=os.path.join(RL_DIR,f"{SUBJ}_{TIME}")
    TMP_F_CB=os.path.join(CB_DIR,f"{SUBJ}_{TIME}")
    if not (os.path.exists(TMP_F) or os.path.exists(TMP_F_LD) or os.path.exists(TMP_F_RL) or os.path.exists(TMP_F_CB)) :
        print(f"NOK pour {SUBJ} : {TMP_F_LD}")
# Out:
# ******************
# M6
# ******************
# NOK pour 640425SV : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/640425SV
# NOK pour 360826MB : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/360826MB
# NOK pour 350517BB : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/350517BB
# NOK pour 371116SD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/371116SD
# NOK pour 320308BD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/320308BD
# NOK pour 380508FP : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/380508FP
# NOK pour 480102CB : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/480102CB
# ******************
# M36
# ******************
# NOK pour 360826MB : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/360826MB
# NOK pour 310501VH : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/310501VH
# NOK pour 371011SG : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/371011SG
# NOK pour 500921XD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/500921XD
# NOK pour 381013FL : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/381013FL
# NOK pour 380508FP : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/380508FP
# NOK pour 480102CB : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/480102CB

# %%
TIME="M6"
TYPE="thickness"
SMT="5"
listJob=!qstat | grep romain | cut -d " " -f3
print(listJob)
print("******************\nM6\n******************")
for SUBJ in df_corr.loc[list(df_air_M6.index.dropna())]['ID_IRM'].dropna() :
    print(f"\033[1;32m {SUBJ}\033[0m")
    if not any([f"M1_{SUBJ}" in elt for elt in listJob]) :
        path_file_lh=os.path.join(BIDS_OUT_DIR,"micapipe_v0.2.0",f"sub-{SUBJ}","ses-2","maps",f"sub-{SUBJ}_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii")
        if not os.path.exists(path_file_lh):
            BIDS_FILE=os.path.join(BIDS_DIR,f"sub-{SUBJ}","ses-2","anat",f"sub-{SUBJ}_ses-2_T1w.nii.gz")
            #TMP_F=os.path.join(TS_PATH,'CTsmoothed',SUBJ+'_'+TIME+"_rh."+TYPE+"."+SMT+".mgh")
            if os.path.exists(BIDS_FILE):
                FS_SUBJ_DIR=""
                if os.path.exists(os.path.join(LD_DIR,SUBJ,f"{SUBJ}_{TIME}")):                    
                    FS_SUBJ_DIR=os.path.join(LD_DIR,SUBJ,f"{SUBJ}_{TIME}")
                elif os.path.exists(os.path.join(RL_DIR,f"{SUBJ}_{TIME}")):
                    FS_SUBJ_DIR=os.path.join(RL_DIR,f"{SUBJ}_{TIME}")
                elif os.path.exists(os.path.join(CB_DIR,f"{SUBJ}_{TIME}")):
                    FS_SUBJ_DIR=os.path.join(CB_DIR,f"{SUBJ}_{TIME}")   
                else :
                    print(f"\033[0;31mNOK pour {SUBJ} : \033[0m")                
                
                if (len(FS_SUBJ_DIR)>0) :
                    CMD_BASH=f"bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe {LOG_DIR} -N M6_{SUBJ} /home/global/micapipe/micapipe -force -sub sub-{SUBJ} -out {BIDS_OUT_DIR} -bids {BIDS_DIR} -ses 2 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir {FS_SUBJ_DIR}"
                    print(CMD_BASH)
                    # !$CMD_BASH
            else :
                print(f"\033[1;31m pas de BIDS pour {SUBJ} : {BIDS_FILE}\033[0m")    
        else :
            print(f"\033[1;32m OK {SUBJ} : {path_file_lh}\033[0m")
    else :
        print(f"\033[1;32m cmd in progress 4 {SUBJ} \033[0m")
# Out:
# []
# ******************
# M6
# ******************
#  510702MFB
#  OK 510702MFB : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-510702MFB/ses-2/maps/sub-510702MFB_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  540724JLC
#  OK 540724JLC : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-540724JLC/ses-2/maps/sub-540724JLC_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  571216AT
#  OK 571216AT : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-571216AT/ses-2/maps/sub-571216AT_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  260410AV
#  OK 260410AV : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-260410AV/ses-2/maps/sub-260410AV_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  350605MM
#  OK 350605MM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-350605MM/ses-2/maps/sub-350605MM_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  640425SV
#  pas de BIDS pour 640425SV : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-640425SV/ses-2/anat/sub-640425SV_ses-2_T1w.nii.gz
#  381020LF
#  OK 381020LF : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-381020LF/ses-2/maps/sub-381020LF_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  300403PP
#  OK 300403PP : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-300403PP/ses-2/maps/sub-300403PP_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  360826MB
#  pas de BIDS pour 360826MB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-360826MB/ses-2/anat/sub-360826MB_ses-2_T1w.nii.gz
#  691229DB
#  OK 691229DB : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-691229DB/ses-2/maps/sub-691229DB_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  511202MS
#  OK 511202MS : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-511202MS/ses-2/maps/sub-511202MS_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  451229MTK
#  OK 451229MTK : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-451229MTK/ses-2/maps/sub-451229MTK_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  320428IM
#  pas de BIDS pour 320428IM : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-320428IM/ses-2/anat/sub-320428IM_ses-2_T1w.nii.gz
#  561020LA
#  OK 561020LA : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-561020LA/ses-2/maps/sub-561020LA_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  440302HP
#  OK 440302HP : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-440302HP/ses-2/maps/sub-440302HP_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  560525GM
#  OK 560525GM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-560525GM/ses-2/maps/sub-560525GM_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  381108JM
#  OK 381108JM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-381108JM/ses-2/maps/sub-381108JM_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  370207MJD
#  OK 370207MJD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-370207MJD/ses-2/maps/sub-370207MJD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  260426RK
#  OK 260426RK : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-260426RK/ses-2/maps/sub-260426RK_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  260409RD
#  OK 260409RD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-260409RD/ses-2/maps/sub-260409RD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  450322MD
#  OK 450322MD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-450322MD/ses-2/maps/sub-450322MD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  310501VH
#  OK 310501VH : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-310501VH/ses-2/maps/sub-310501VH_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  231023MB
#  OK 231023MB : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-231023MB/ses-2/maps/sub-231023MB_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#
: /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-501120PAC/ses-2/maps/sub-501120PAC_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  460711ML
#  OK 460711ML : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-460711ML/ses-2/maps/sub-460711ML_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  360912LD
#  OK 360912LD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-360912LD/ses-2/maps/sub-360912LD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  680930WD
#  OK 680930WD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-680930WD/ses-2/maps/sub-680930WD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  400504GD
#  OK 400504GD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-400504GD/ses-2/maps/sub-400504GD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  490508DS
#  OK 490508DS : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-490508DS/ses-2/maps/sub-490508DS_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  380508FP
#  pas de BIDS pour 380508FP : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-380508FP/ses-2/anat/sub-380508FP_ses-2_T1w.nii.gz
#  510816JM
#  OK 510816JM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-510816JM/ses-2/maps/sub-510816JM_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  391120GA
#  OK 391120GA : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-391120GA/ses-2/maps/sub-391120GA_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  390720GM
#  OK 390720GM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-390720GM/ses-2/maps/sub-390720GM_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  360618RD
#  OK 360618RD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-360618RD/ses-2/maps/sub-360618RD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  761229PN
#  OK 761229PN : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-761229PN/ses-2/maps/sub-761229PN_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  620204BD
#  OK 620204BD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-620204BD/ses-2/maps/sub-620204BD_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  611230FJ
#  OK 611230FJ : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-611230FJ/ses-2/maps/sub-611230FJ_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  430217YI
#  OK 430217YI : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-430217YI/ses-2/maps/sub-430217YI_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  371202DJP
#  OK 371202DJP : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-371202DJP/ses-2/maps/sub-371202DJP_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  361004MV
#  OK 361004MV : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-361004MV/ses-2/maps/sub-361004MV_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  480102CB
#  pas de BIDS pour 480102CB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-480102CB/ses-2/anat/sub-480102CB_ses-2_T1w.nii.gz
#  470924PV
#  OK 470924PV : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-470924PV/ses-2/maps/sub-470924PV_ses-2_hemi-L_surf-fsaverage5_label-thickness.func.gii

# %%
TIME="M36"
TYPE="thickness"
SMT="5"
listJob=!qstat | grep romain | cut -d " " -f3
print(listJob)
print("******************\nM36\n******************")
for SUBJ in df_corr.loc[list(df_air_M36.index.dropna())]['ID_IRM'].dropna() :
    print(f"\033[1;32m {SUBJ}\033[0m")
    if not any([f"M1_{SUBJ}" in elt for elt in listJob]) :
        path_file_lh=os.path.join(BIDS_OUT_DIR,"micapipe_v0.2.0",f"sub-{SUBJ}","ses-3","maps",f"sub-{SUBJ}_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii")
        if not os.path.exists(path_file_lh):
            BIDS_FILE=os.path.join(BIDS_DIR,f"sub-{SUBJ}","ses-3","anat",f"sub-{SUBJ}_ses-3_T1w.nii.gz")
            #TMP_F=os.path.join(TS_PATH,'CTsmoothed',SUBJ+'_'+TIME+"_rh."+TYPE+"."+SMT+".mgh")
            if os.path.exists(BIDS_FILE):
                FS_SUBJ_DIR=""
                if os.path.exists(os.path.join(LD_DIR,SUBJ,f"{SUBJ}_{TIME}")):                    
                    FS_SUBJ_DIR=os.path.join(LD_DIR,SUBJ,f"{SUBJ}_{TIME}")
                elif os.path.exists(os.path.join(RL_DIR,f"{SUBJ}_{TIME}")):
                    FS_SUBJ_DIR=os.path.join(RL_DIR,f"{SUBJ}_{TIME}")
                elif os.path.exists(os.path.join(CB_DIR,f"{SUBJ}_{TIME}")):
                    FS_SUBJ_DIR=os.path.join(CB_DIR,f"{SUBJ}_{TIME}")   
                else :
                    print(f"\033[0;31mNOK pour {SUBJ} : \033[0m")                
                
                if (len(FS_SUBJ_DIR)>0) :
                    CMD_BASH=f"bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe {LOG_DIR} -N M36_{SUBJ} /home/global/micapipe/micapipe -force -sub sub-{SUBJ} -out {BIDS_OUT_DIR} -bids {BIDS_DIR} -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir {FS_SUBJ_DIR}"
                    print(CMD_BASH)
                    # !$CMD_BASH
            else :
                print(f"\033[1;31m pas de BIDS pour {SUBJ} : {BIDS_FILE}\033[0m")    
        else :
            print(f"\033[1;32m OK {SUBJ} : {path_file_lh}\033[0m")
    else :
        print(f"\033[1;32m cmd in progress 4 {SUBJ} \033[0m")
# Out:
# ['M6_680917A', 'M6_450912B']
# ******************
# M36
# ******************
#  510702MFB
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_510702MFB /home/global/micapipe/micapipe -force -sub sub-510702MFB -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/510702MFB_M36
#  571216AT
#  OK 571216AT : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-571216AT/ses-3/maps/sub-571216AT_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  260410AV
#  OK 260410AV : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-260410AV/ses-3/maps/sub-260410AV_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  350605MM
#  OK 350605MM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-350605MM/ses-3/maps/sub-350605MM_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  381020LF
#  OK 381020LF : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-381020LF/ses-3/maps/sub-381020LF_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  360826MB
#  pas de BIDS pour 360826MB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-360826MB/ses-3/anat/sub-360826MB_ses-3_T1w.nii.gz
#  691229DB
#  OK 691229DB : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-691229DB/ses-3/maps/sub-691229DB_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  511202MS
#  OK 511202MS : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-511202MS/ses-3/maps/sub-511202MS_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  270525RL
#  OK 270525RL : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-270525RL/ses-3/maps/sub-270525RL_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  451229MTK
#  pas de BIDS pour 451229MTK : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-451229MTK/ses-3/anat/sub-451229MTK_ses-3_T1w.nii.gz
#  561020LA
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_561020LA /home/global/micapipe/micapipe -force -sub sub-561020LA -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/561020LA_M36
#  440302HP
#  OK 440302HP : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-440302HP/ses-3/maps/sub-440302HP_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  381108JM
#  OK 381108JM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-381108JM/ses-3/maps/sub-381108JM_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  580620CG
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_580620CG /home/global/micapipe/micapipe -force -sub sub-580620CG -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/580620CG_M36
#  421020JL
#  OK 421020JL : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-421020JL/ses-3/maps/sub-421020JL_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  370207MJD
#  OK 370207MJD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-370207MJD/ses-3/maps/sub-370207MJD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  260426RK
#  pas de BIDS pour 260426RK : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-260426RK/ses-3/anat/sub-260426RK_ses-3_T1w.nii.gz
#  581002PR
#  OK 581002PR : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-581002PR/ses-3/maps/sub-581002PR_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  450322MD
#  OK 450322MD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-450322MD/ses-3/maps/sub-450322MD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  310501VH
#  pas de BIDS pour 310501VH : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-310501VH/ses-3/anat/sub-310501VH_ses-3_T1w.nii.gz
#  540412AB
#  OK 540412AB : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-540412AB/ses-3/maps/sub-540412AB_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  421028RB
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_421028RB /home/global/micapipe/micapipe -force -sub sub-421028RB -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/421028RB_M36
#  460121DD
#  OK 460121DD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-460121DD/ses-3/maps/sub-460121DD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  500522FM
#  OK 500522FM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-500522FM/ses-3/maps/sub-500522FM_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  550721AL
#  OK 550721AL : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-550721AL/ses-3/maps/sub-550721AL_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  680917AG
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_680917AG /home/global/micapipe/micapipe -force -sub sub-680917AG -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/680917AG_M36
#  510506NP
#  pas de BIDS pour 510506NP : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-510506NP/ses-3/anat/sub-510506NP_ses-3_T1w.nii.gz
#  290729JL
#  OK 290729JL : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-290729JL/ses-3/maps/sub-290729JL_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  461113JMD
#  OK 461113JMD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-461113JMD/ses-3/maps/sub-461113JMD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  380919MD
#  OK 380919MD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-380919MD/ses-3/maps/sub-380919MD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  520907MD
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_520907MD /home/global/micapipe/micapipe -force -sub sub-520907MD -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/520907MD_M36
#  490401AD
#  pas de BIDS pour 490401AD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-490401AD/ses-3/anat/sub-490401AD_ses-3_T1w.nii.gz
#  321230AL
#  OK 321230AL : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-321230AL/ses-3/maps/sub-321230AL_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  390217JF
#  pas de BIDS pour 390217JF : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-390217JF/ses-3/anat/sub-390217JF_ses-3_T1w.nii.gz
#  670806JPP
#  OK 670806JPP : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-670806JPP/ses-3/maps/sub-670806JPP_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  610612HV
#  OK 610612HV : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-610612HV/ses-3/maps/sub-610612HV_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  530512AS
#  OK 530512AS : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-530512AS/ses-3/maps/sub-530512AS_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  450906AM
#  OK 450906AM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-450906AM/ses-3/maps/sub-450906AM_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  541027GL
#  pas de BIDS pour 541027GL : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-541027GL/ses-3/anat/sub-541027GL_ses-3_T1w.nii.gz
#  610415JD
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_610415JD /home/global/micapipe/micapipe -force -sub sub-610415JD -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/610415JD_M36
#  450912BH
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_450912BH /home/global/micapipe/micapipe -force -sub sub-450912BH -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/450912BH_M36
#  490105RM
#  OK 490105RM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-490105RM/ses-3/maps/sub-490105RM_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  350612JG
#  OK 350612JG : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-350612JG/ses-3/maps/sub-350612JG_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  600816JLS
#  OK 600816JLS : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-600816JLS/ses-3/maps/sub-600816JLS_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  431119AM
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_431119AM /home/global/micapipe/micapipe -force -sub sub-431119AM -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/431119AM_M36
#  600506GH
#  OK 600506GH : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-600506GH/ses-3/maps/sub-600506GH_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  251214JD
#  pas de BIDS pour 251214JD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-251214JD/ses-3/anat/sub-251214JD_ses-3_T1w.nii.gz
#  430602SD
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_430602SD /home/global/micapipe/micapipe -force -sub sub-430602SD -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/430602SD_M36
#  491228CD
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_491228CD /home/global/micapipe/micapipe -force -sub sub-491228CD -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/491228CD_M36
#  500328AR
#  OK 500328AR : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-500328AR/ses-3/maps/sub-500328AR_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  460412CT
#  OK 460412CT : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-460412CT/ses-3/maps/sub-460412CT_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  720501GL
#  OK 720501GL : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-720501GL/ses-3/maps/sub-720501GL_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  310109JP
#  OK 310109JP : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-310109JP/ses-3/maps/sub-310109JP_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  690408PM
#  pas de BIDS pour 690408PM : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-690408PM/ses-3/anat/sub-690408PM_ses-3_T1w.nii.gz
#  520821EC
#  OK 520821EC : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-520821EC/ses-3/maps/sub-520821EC_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  420220EM
#  OK 420220EM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-420220EM/ses-3/maps/sub-420220EM_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  540205BB
#  pas de BIDS pour 540205BB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-540205BB/ses-3/anat/sub-540205BB_ses-3_T1w.nii.gz
#  540310PE
#  OK 540310PE : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-540310PE/ses-3/maps/sub-540310PE_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  731001LC
#  OK 731001LC : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-731001LC/ses-3/maps/sub-731001LC_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  330930MD
#  OK 330930MD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-330930MD/ses-3/maps/sub-330930MD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  561230PV
#  OK 561230PV : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-561230PV/ses-3/maps/sub-561230PV_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  430109MD
#  OK 430109MD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-430109MD/ses-3/maps/sub-430109MD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  350112GC
#  OK 350112GC : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-350112GC/ses-3/maps/sub-350112GC_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  510915PD
#  OK 510915PD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-510915PD/ses-3/maps/sub-510915PD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  391216FD
#  OK 391216FD : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-391216FD/ses-3/maps/sub-391216FD_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  310317GD
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_310317GD /home/global/micapipe/micapipe -force -sub sub-310317GD -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/310317GD_M36
#  420919CB
#  pas de BIDS pour 420919CB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-420919CB/ses-3/anat/sub-420919CB_ses-3_T1w.nii.gz
#  530816CG
#  OK 530816CG : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-530816CG/ses-3/maps/sub-530816CG_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  490301AC
#  OK 490301AC : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-490301AC/ses-3/maps/sub-490301AC_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  630418CM
#  OK 630418CM : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-630418CM/ses-3/maps/sub-630418CM_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  521029PB
#  OK 521029PB : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-521029PB/ses-3/maps/sub-521029PB_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  380126NB
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_380126NB /home/global/micapipe/micapipe -force -sub sub-380126NB -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/380126NB_M36
#  440718YT
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_440718YT /home/global/micapipe/micapipe -force -sub sub-440718YT -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/440718YT_M36
#  371011SG
#  pas de BIDS pour 371011SG : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-371011SG/ses-3/anat/sub-371011SG_ses-3_T1w.nii.gz
#  340303JV
# NOK pour 340303JV :
#  510718CP
#  OK 510718CP : /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2/micapipe_v0.2.0/sub-510718CP/ses-3/maps/sub-510718CP_ses-3_hemi-L_surf-fsaverage5_label-thickness.func.gii
#  380614FS
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_380614FS /home/global/micapipe/micapipe -force -sub sub-380614FS -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/380614FS_M36
#  400317AC
# NOK pour 400317AC :
#  470101MT
# NOK pour 470101MT :
#  520214ML
# NOK pour 520214ML :
#  580714PF
# NOK pour 580714PF :
#  490226YB
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_490226YB /home/global/micapipe/micapipe -force -sub sub-490226YB -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/490226YB_M36
#  420203JL
# NOK pour 420203JL :
#  671019NL
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_671019NL /home/global/micapipe/micapipe -force -sub sub-671019NL -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/671019NL_M36
#  560413DC
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_560413DC /home/global/micapipe/micapipe -force -sub sub-560413DC -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/560413DC_M36
#  470327JPE
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_470327JPE /home/global/micapipe/micapipe -force -sub sub-470327JPE -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/470327JPE_M36
#  371218ET
#  pas de BIDS pour 371218ET : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-371218ET/ses-3/anat/sub-371218ET_ses-3_T1w.nii.gz
#  690526CR
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_690526CR /home/global/micapipe/micapipe -force -sub sub-690526CR -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/690526CR_M36
#  420608JD
# NOK pour 420608JD :
#  810305BB
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_810305BB /home/global/micapipe/micapipe -force -sub sub-810305BB -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/810305BB_M36
#  570226LD
#  pas de BIDS pour 570226LD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-570226LD/ses-3/anat/sub-570226LD_ses-3_T1w.nii.gz
#  500921XD
# NOK pour 500921XD :
#  840909AD
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_840909AD /home/global/micapipe/micapipe -force -sub sub-840909AD -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/840909AD_M36
#  690510ND
# NOK pour 690510ND :
#  500628MW
# NOK pour 500628MW :
#  670213PC
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_670213PC /home/global/micapipe/micapipe -force -sub sub-670213PC -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/670213PC_M36
#  521008BT
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_521008BT /home/global/micapipe/micapipe -force -sub sub-521008BT -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/521008BT_M36
#  601224NLL
# NOK pour 601224NLL :
#  290318AB
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_290318AB /home/global/micapipe/micapipe -force -sub sub-290318AB -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/290318AB_M36
#  370921BW
# NOK pour 370921BW :
#  531122JCD
# bash /NAS/deathrow/vincent/my_qbatch.sh -q two_job_q -oe /NAS/tupac/protocoles/Strokdem/TractSeg/code/log -N M36_531122JCD /home/global/micapipe/micapipe -force -sub sub-531122JCD -out /NAS/deathrow/renaud/dti_disconnection/bids_db/derivatives2 -bids /NAS/deathrow/renaud/dti_disconnection/bids_db -ses 3 -fs_licence /home/global/freesurfer7.1/license.txt -proc_structural -proc_surf -post_structural -freesurfer -surf_dir /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/531122JCD_M36
#  680518AH
#  pas de BIDS pour 680518AH : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-680518AH/ses-3/anat/sub-680518AH_ses-3_T1w.nii.gz
#  630618AF
# NOK pour 630618AF :
#  381013FL
#  pas de BIDS pour 381013FL : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-381013FL/ses-3/anat/sub-381013FL_ses-3_T1w.nii.gz
#  480303JL
# NOK pour 480303JL :
#  501120PAC
# NOK pour 501120PAC :
#  460711ML
# NOK pour 460711ML :
#  360912LD
# NOK pour 360912LD :
#  680930WD
# NOK pour 680930WD :
#  490508DS
# NOK pour 490508DS :
#  380508FP
#  pas de BIDS pour 380508FP : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-380508FP/ses-3/anat/sub-380508FP_ses-3_T1w.nii.gz
#  510816JM
# NOK pour 510816JM :
#  391120GA
# NOK pour 391120GA :
#  390720GM
# NOK pour 390720GM :
#  360618RD
# NOK pour 360618RD :
#  761229PN
# NOK pour 761229PN :
#  620204BD
#  pas de BIDS pour 620204BD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-620204BD/ses-3/anat/sub-620204BD_ses-3_T1w.nii.gz
#  611230FJ
# NOK pour 611230FJ :
#  430217YI
# NOK pour 430217YI :
#  361004MV
# NOK pour 361004MV :
#  480102CB
#  pas de BIDS pour 480102CB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-480102CB/ses-3/anat/sub-480102CB_ses-3_T1w.nii.gz
#  470924PV
# NOK pour 470924PV :

# %%
print("******************\nM36\n******************")
TIME="M36"
for SUBJ in df_corr.loc[list(df_air_M36.index.dropna())]['ID_IRM'].dropna() :
    BIDS_FILE=os.path.join(BIDS_DIR,f"sub-{SUBJ}","ses-3","anat",f"sub-{SUBJ}_ses-3_T1w.nii.gz")
    #TMP_F=os.path.join(TS_PATH,'CTsmoothed',SUBJ+'_'+TIME+"_rh."+TYPE+"."+SMT+".mgh")
    TMP_F_LD=os.path.join(LD_DIR,SUBJ,f"{SUBJ}_{TIME}")
    TMP_F_RL=os.path.join(RL_DIR,SUBJ,f"{SUBJ}_{TIME}")
    TMP_F_CB=os.path.join(CB_DIR,f"{SUBJ}_{TIME}")
    if os.path.exists(BIDS_FILE):
        if os.path.exists(TMP_F_LD):
            print(f"\033[0;32m{TMP_F_LD}\033[0m")
       # elif os.path.exists(TMP_F):
       #     print(f"\033[0;33m{TMP_F}\033[0m")
        elif os.path.exists(TMP_F_RL):
            print(f"\033[0;33m{TMP_F_RL}\033[0m")
        elif os.path.exists(TMP_F_CB):
            print(f"\033[0;33m{TMP_F_CB}\033[0m")
        else :
            print(f"\033[0;31mNOK pour {SUBJ} : {TMP_F_LD}\033[0m")
    else :        
        print(f"\033[1;31m pas de BIDS pour {SUBJ} : {BIDS_FILE}\033[0m")
        DIR_3DT1=os.path.join(STUDY_PATH,"data",f"{SUBJ}",f"{SUBJ}_M36")
        print(f"\033[1;31m ls {DIR_3DT1}/*.nii.gz \033[0m")
# Out:
# ******************
# M36
# ******************
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/510702MFB_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/571216AT_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/260410AV_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/350605MM_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/381020LF_M36
#  pas de BIDS pour 360826MB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-360826MB/ses-3/anat/sub-360826MB_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/360826MB/360826MB_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/691229DB_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/511202MS_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/270525RL_M36
#  pas de BIDS pour 451229MTK : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-451229MTK/ses-3/anat/sub-451229MTK_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/451229MTK/451229MTK_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/561020LA_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/440302HP_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/381108JM_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/580620CG_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/421020JL_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/370207MJD_M36
#  pas de BIDS pour 260426RK : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-260426RK/ses-3/anat/sub-260426RK_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/260426RK/260426RK_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/581002PR_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/450322MD_M36
#  pas de BIDS pour 310501VH : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-310501VH/ses-3/anat/sub-310501VH_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/310501VH/310501VH_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/540412AB_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/421028RB_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/460121DD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/500522FM_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/550721AL_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/680917AG_M36
#  pas de BIDS pour 510506NP : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-510506NP/ses-3/anat/sub-510506NP_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/510506NP/510506NP_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/290729JL_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/461113JMD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/380919MD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/520907MD_M36
#  pas de BIDS pour 490401AD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-490401AD/ses-3/anat/sub-490401AD_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/490401AD/490401AD_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/321230AL_M36
#  pas de BIDS pour 390217JF : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-390217JF/ses-3/anat/sub-390217JF_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/390217JF/390217JF_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/670806JPP_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/610612HV_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/530512AS_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/450906AM_M36
#  pas de BIDS pour 541027GL : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-541027GL/ses-3/anat/sub-541027GL_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/541027GL/541027GL_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/610415JD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/450912BH_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/490105RM_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/350612JG_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/600816JLS_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/431119AM_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/600506GH_M36
#  pas de BIDS pour 251214JD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-251214JD/ses-3/anat/sub-251214JD_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/251214JD/251214JD_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/430602SD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/491228CD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/500328AR_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/460412CT_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/720501GL_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/310109JP_M36
#  pas de BIDS pour 690408PM : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-690408PM/ses-3/anat/sub-690408PM_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/690408PM/690408PM_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/520821EC_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/420220EM_M36
#  pas de BIDS pour 540205BB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-540205BB/ses-3/anat/sub-540205BB_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/540205BB/540205BB_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/540310PE_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/731001LC_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/330930MD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/561230PV_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/430109MD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/350112GC_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/510915PD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/391216FD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/310317GD_M36
#  pas de BIDS pour 420919CB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-420919CB/ses-3/anat/sub-420919CB_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/420919CB/420919CB_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/530816CG_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/490301AC_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/630418CM_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/521029PB_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/380126NB_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/440718YT_M36
#  pas de BIDS pour 371011SG : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-371011SG/ses-3/anat/sub-371011SG_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/371011SG/371011SG_M36/*.nii.gz
# NOK pour 340303JV : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/340303JV/340303JV_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/510718CP_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/380614FS_M36
# NOK pour 400317AC : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/400317AC/400317AC_M36
# NOK pour 470101MT : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/470101MT/470101MT_M36
# NOK pour 520214ML : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/520214ML/520214ML_M36
# NOK pour 580714PF : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/580714PF/580714PF_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/490226YB_M36
# NOK pour 420203JL : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/420203JL/420203JL_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/671019NL_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/560413DC_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/470327JPE_M36
#  pas de BIDS pour 371218ET : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-371218ET/ses-3/anat/sub-371218ET_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/371218ET/371218ET_M36/*.nii.gz
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/690526CR_M36
# NOK pour 420608JD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/420608JD/420608JD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/810305BB_M36
#  pas de BIDS pour 570226LD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-570226LD/ses-3/anat/sub-570226LD_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/570226LD/570226LD_M36/*.nii.gz
# NOK pour 500921XD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/500921XD/500921XD_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/840909AD_M36
# NOK pour 690510ND : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/690510ND/690510ND_M36
# NOK pour 500628MW : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/500628MW/500628MW_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/670213PC_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/521008BT_M36
# NOK pour 601224NLL : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/601224NLL/601224NLL_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/290318AB_M36
# NOK pour 370921BW : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/370921BW/370921BW_M36
# /NAS/tupac/protocoles/Strokdem/FS5.1_T2mask/531122JCD_M36
#  pas de BIDS pour 680518AH : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-680518AH/ses-3/anat/sub-680518AH_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/680518AH/680518AH_M36/*.nii.gz
# NOK pour 630618AF : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/630618AF/630618AF_M36
#  pas de BIDS pour 381013FL : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-381013FL/ses-3/anat/sub-381013FL_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/381013FL/381013FL_M36/*.nii.gz
# NOK pour 480303JL : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/480303JL/480303JL_M36
# NOK pour 501120PAC : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/501120PAC/501120PAC_M36
# NOK pour 460711ML : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/460711ML/460711ML_M36
# NOK pour 360912LD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/360912LD/360912LD_M36
# NOK pour 680930WD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/680930WD/680930WD_M36
# NOK pour 490508DS : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/490508DS/490508DS_M36
#  pas de BIDS pour 380508FP : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-380508FP/ses-3/anat/sub-380508FP_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/380508FP/380508FP_M36/*.nii.gz
# NOK pour 510816JM : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/510816JM/510816JM_M36
# NOK pour 391120GA : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/391120GA/391120GA_M36
# NOK pour 390720GM : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/390720GM/390720GM_M36
# NOK pour 360618RD : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/360618RD/360618RD_M36
# NOK pour 761229PN : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/761229PN/761229PN_M36
#  pas de BIDS pour 620204BD : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-620204BD/ses-3/anat/sub-620204BD_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/620204BD/620204BD_M36/*.nii.gz
# NOK pour 611230FJ : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/611230FJ/611230FJ_M36
# NOK pour 430217YI : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/430217YI/430217YI_M36
# NOK pour 361004MV : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/361004MV/361004MV_M36
#  pas de BIDS pour 480102CB : /NAS/deathrow/renaud/dti_disconnection/bids_db/sub-480102CB/ses-3/anat/sub-480102CB_ses-3_T1w.nii.gz
#  ls /NAS/tupac/protocoles/Strokdem/data/480102CB/480102CB_M36/*.nii.gz
# NOK pour 470924PV : /NAS/tupac/protocoles/Strokdem/Radiomique_SB_LoicDuron_2021/FreeSurfer_Output/470924PV/470924PV_M36
